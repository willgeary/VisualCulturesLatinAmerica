# %%
import urllib
import os
import math

api_key = "AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI"

# %%
def getStreetViewImages(addresses, heading, pitch, key, geojson=False):
    count=0
    coords = addresses['features'][0]['geometry']['coordinates']
    lats = [i[1] for i in coords]
    lons = [i[0] for i in coords]
    for coord in coords:
        #for h in headings:
        base = "https://maps.googleapis.com/maps/api/streetview?size=1200x800&location={0}&heading={1}&pitch={2}&key={3}"
        coord_string = str([coord[1],coord[0]]).replace("[","").replace("]","")
        request_url = base.format(coord_string, heading, pitch, key)
        print request_url
        figname = str(count) + "_" + str(heading) + "_" + str(pitch) + ".jpg"
        urllib.urlretrieve(request_url, os.path.join(os.getcwd(),figname))
        count +=1

# %%
lineString = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "LineString",
        "coordinates": [
          [
            -74.08999443054199,
            4.582157234736653
          ],
          [
            -74.08930778503418,
            4.582927241533883
          ],
          [
            -74.08862113952637,
            4.583697247501639
          ],
          [
            -74.08793449401855,
            4.584467252639753
          ],
          [
            -74.08733367919922,
            4.585408368903904
          ],
          [
            -74.08681869506836,
            4.586178372197907
          ],
          [
            -74.0863037109375,
            4.5871194862077065
          ],
          [
            -74.08570289611816,
            4.587718376295499
          ],
          [
            -74.08510208129883,
            4.588745043848723
          ],
          [
            -74.08450126647949,
            4.589771709925458
          ],
          [
            -74.08407211303711,
            4.59054170851383
          ],
          [
            -74.0833854675293,
            4.5914828167712916
          ],
          [
            -74.08304214477539,
            4.592081703197872
          ],
          [
            -74.082612991333,
            4.592680589121669
          ],
          [
            -74.08209800720215,
            4.593621694557355
          ],
          [
            -74.08141136169434,
            4.5943061340941425
          ],
          [
            -74.08098220825194,
            4.594905018149873
          ],
          [
            -74.0804672241211,
            4.595675011196574
          ],
          [
            -74.08012390136719,
            4.596359448762016
          ],
          [
            -74.07995223999023,
            4.5969583310925755
          ],
          [
            -74.07952308654785,
            4.597557212919832
          ],
          [
            -74.07909393310547,
            4.598070539799691
          ],
          [
            -74.07875061035156,
            4.598840529425947
          ],
          [
            -74.07832145690918,
            4.599439409670928
          ],
          [
            -74.0778923034668,
            4.599952735194369
          ],
          [
            -74.07746315002441,
            4.600808276911184
          ],
          [
            -74.07694816589355,
            4.601407155501272
          ],
          [
            -74.07660484313965,
            4.602091587558756
          ],
          [
            -74.07617568969727,
            4.602519357260504
          ],
          [
            -74.07591819763184,
            4.603203788248495
          ],
          [
            -74.07548904418945,
            4.603717111057511
          ],
          [
            -74.0749740600586,
            4.604743755564512
          ],
          [
            -74.07471656799315,
            4.60525707726242
          ],
          [
            -74.07437324523926,
            4.605599291521902
          ],
          [
            -74.07394409179688,
            4.606198166079785
          ],
          [
            -74.07351493835449,
            4.606797040133346
          ]
        ]
      }
    }
  ]
}

# %%
getStreetViewImages(lineString, heading=90, pitch=0, key=api_key, geojson=True)
# Out:
# https://maps.googleapis.com/maps/api/streetview?size=1200x800&location=4.582157234736653, -74.08999443054199&heading=90&pitch=0&key=AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI
# https://maps.googleapis.com/maps/api/streetview?size=1200x800&location=4.582927241533883, -74.08930778503418&heading=90&pitch=0&key=AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI
# https://maps.googleapis.com/maps/api/streetview?size=1200x800&location=4.583697247501639, -74.08862113952637&heading=90&pitch=0&key=AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI
# https://maps.googleapis.com/maps/api/streetview?size=1200x800&location=4.584467252639753, -74.08793449401855&heading=90&pitch=0&key=AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI
# https://maps.googleapis.com/maps/api/streetview?size=1200x800&location=4.585408368903904, -74.08733367919922&heading=90&pitch=0&key=AIzaSyBAoPdlU72RTD-AzCgjNag0zE6RxSKGEPI
# ...
